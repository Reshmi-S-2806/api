# %%
import requests
import json
# API ENDPOINT
url="https://api.restful-api.dev/objects"
# SEND GET request
response = requests.get(url)

# json response
data=response.json()
print("response json data")
print(data)
# Out:
# response json data
# {'id': 'ff8081819f7e10ae019fd9f89adc06aa', 'name': 'John Doe', 'data': {'color': 'red', 'capacity': '128 GB'}}

# %%
import requests
import json
url="https://api.restful-api.dev/objects"
payload = {
    'name': "John Doe",
    'data': {'color': 'red', 'capacity':'128 GB'}
}
header={
    'Content-Type': 'application/json'}
response = requests.post(url, data=json.dumps(payload), headers=header)
if response.status_code == 200:
    print("POST request successful")
    print(response.json())
else:
    print("POST request failed with status code:", response.status_code)
# Out:
# POST request successful
# {'id': 'ff8081819f7e10ae019fd9f89adc06aa', 'name': 'John Doe', 'createdAt': 1786068376284, 'data': {'color': 'red', 'capacity': '128 GB'}}

# %%
import requests
import json
# API ENDPOINT
url="https://api.restful-api.dev/objects/ff8081819f7e10ae019fd9f89adc06aa"
# SEND GET request
response = requests.get(url)

# json response
data=response.json()
print("response json data")
print(data)
